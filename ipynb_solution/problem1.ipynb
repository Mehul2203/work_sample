# %%
# importing required libraries
import pandas as pd
import numpy as np
import os
import dask.dataframe as dd

# %%
# function for creating a dataframe of security name and Symbol from the meta data file 

def reading_metadata(location):
    #reading metadata information
    meta_df = pd.read_csv(location)

    #keeping_only_reqd_cols from metadata_df
    meta_df = meta_df[['Security Name', 'Symbol']]
    return meta_df

# %%
meta_df = reading_metadata("symbols_valid_meta.csv")
meta_df
# Out:
#                                           Security Name Symbol
# 0               Agilent Technologies, Inc. Common Stock      A
# 1                       Alcoa Corporation Common Stock      AA
# 2                          Perth Mint Physical Gold ETF   AAAU
# 3     ATA Creativity Global - American Depositary Sh...   AACG
# 4                   AdvisorShares Dorsey Wright ADR ETF   AADR
# ...                                                 ...    ...
# 8044                   Zuora, Inc. Class A Common Stock    ZUO
# 8045                          Zovio Inc. - Common Stock    ZVO
# 8046                       Zymeworks Inc. Common Shares   ZYME
# 8047       Zynerba Pharmaceuticals, Inc. - Common Stock   ZYNE
# 8048                         Zynex, Inc. - Common Stock   ZYXI
#
# [8049 rows x 2 columns]

# %%
# function for creating a list of tuples with file names and file locations
# csv files of both ETF and stock are saved in a single folder called as directory

def get_file_details(directory):
    nested_dir = os.listdir(directory)
    files = []
    for file in os.listdir(directory+"/"):
        files.append((file, directory+"/"+file))
    return files

# %%
a = get_file_details('directory')
a
# Out:
# [('A.csv', 'directory/A.csv'),
#  ('AA.csv', 'directory/AA.csv'),
#  ('AAAU.csv', 'directory/AAAU.csv'),
#  ('AACG.csv', 'directory/AACG.csv'),
#  ('AADR.csv', 'directory/AADR.csv'),
#  ('AAL.csv', 'directory/AAL.csv'),
#  ('AAMC.csv', 'directory/AAMC.csv'),
#  ('AAME.csv', 'directory/AAME.csv'),
#  ('AAN.csv', 'directory/AAN.csv'),
#  ('AAOI.csv', 'directory/AAOI.csv'),
#  ('AAON.csv', 'directory/AAON.csv'),
#  ('AAP.csv', 'directory/AAP.csv'),
#  ('AAPL.csv', 'directory/AAPL.csv'),
#  ('AAT.csv', 'directory/AAT.csv'),
#  ('AAU.csv', 'directory/AAU.csv'),
#  ('AAWW.csv', 'directory/AAWW.csv'),
#  ('AAXJ.csv', 'directory/AAXJ.csv'),
#  ('AAXN.csv', 'directory/AAXN.csv'),
#  ('AB.csv', 'directory/AB.csv'),
#  ('ABB.csv', 'directory/ABB.csv'),
#  ('ABBV.csv', 'directory/ABBV.csv'),
#  ('ABC.csv', 'directory/ABC.csv'),
#  ('ABCB.csv', 'directory/ABCB.csv'),
#  ('ABEO.csv', 'directory/ABEO.csv'),
#  ('ABEQ.csv', 'directory/ABEQ.csv'),
#  ('ABEV.csv', 'directory/ABEV.csv'),
#  ('ABG.csv', 'directory/ABG.csv'),
#  ('ABIO.csv', 'directory/ABIO.csv'),
#  ('ABM.csv', 'directory/ABM.csv'),
#  ('ABMD.csv', 'directory/ABMD.csv'),
#  ('ABR.csv', 'directory/ABR.csv'),
#  ('ABT.csv', 'directory/ABT.csv'),
#  ('ABTX.csv', 'directory/ABTX.csv'),
#  ('ABUS.csv', 'directory/ABUS.csv'),
#  ('AC.csv', 'directory/AC.csv'),
#  ('ACA.csv', 'directory/ACA.csv'),
#  ('ACAD.csv', 'directory/ACAD.csv'),
#  ('ACAM.csv', 'directory/ACAM.csv'),
#  ('ACAMU.csv', 'directory/ACAMU.csv'),
#  ('ACB.csv', 'directory/ACB.csv'),
#  ('ACBI.csv', 'directory/ACBI.csv'),
#  ('ACC.csv', 'directory/ACC.csv'),
#  ('ACCO.csv', 'directory/ACCO.csv'),
#  ('ACEL.csv', 'directory/ACEL.csv'),
#  ('ACER.csv', 'directory/ACER.csv'),
#  ('ACES.csv', 'directory/ACES.csv'),
#  ('ACGL.csv', 'directory/ACGL.csv'),
#  ('ACGLO.csv', 'directory/ACGLO.csv'),
#  ('ACGLP.csv', 'directory/ACGLP.csv'),
#  ('ACH.csv', 'directory/ACH.csv'),
#  ('ACHC.csv', 'directory/ACHC.csv'),
#  ('ACHV.csv', 'directory/ACHV.csv'),
#  ('ACIA.csv', 'directory/ACIA.csv'),
#  ('ACIO.csv', 'directory/ACIO.csv'),
#  ('ACIU.csv', 'directory/ACIU.csv'),
#  ('ACIW.csv', 'directory/ACIW.csv'),
#  ('ACLS.csv', 'directory/ACLS.csv'),
#  ('ACM.csv', 'directory/ACM.csv'),
#  ('ACMR.csv', 'directory/ACMR.csv'),
#  ('ACN.csv', 'directory/ACN.csv'),
#  ('ACNB.csv', 'directory/ACNB.csv'),
#  ('ACOR.csv', 'directory/ACOR.csv'),
#  ('ACP.csv', 'directory/ACP.csv'),
#  ('ACRE.csv', 'directory/ACRE.csv'),
#  ('ACRS.csv', 'directory/ACRS.csv'),
#  ('ACRX.csv', 'directory/ACRX.csv'),
#  ('ACSG.csv', 'directory/ACSG.csv'),
#  ('ACSI.csv', 'directory/ACSI.csv'),
#  ('ACST.csv', 'directory/ACST.csv'),
#  ('ACT.csv', 'directory/ACT.csv'),
#  ('ACTG.csv', 'directory/ACTG.csv'),
#  ('ACTT.csv', 'directory/ACTT.csv'),
#  ('ACTTU.csv', 'directory/ACTTU.csv'),
#  ('ACU.csv', 'directory/ACU.csv'),
#  ('ACV.csv', 'directory/ACV.csv'),
#  ('ACWF.csv', 'directory/ACWF.csv'),
#  ('ACWI.csv', 'directory/ACWI.csv'),
#  ('ACWV.csv', 'directory/ACWV.csv'),
#  ('ACWX.csv', 'directory/ACWX.csv'),
#  ('ACY.csv', 'directory/ACY.csv'),
#  ('ADAP.csv', 'directory/ADAP.csv'),
#  ('ADBE.csv', 'directory/ADBE.csv'),
#  ('ADC.csv', 'directory/ADC.csv'),
#  ('ADES.csv', 'directory/ADES.csv'),
#  ('ADI.csv', 'directory/ADI.csv'),
#  ('ADIL.csv', 'directory/ADIL.csv'),
#  ('ADM.csv', 'directory/ADM.csv'),
#  ('ADMA.csv', 'directory/ADMA.csv'),
#  ('ADME.csv', 'directory/ADME.csv'),
#  ('ADMP.csv', 'directory/ADMP.csv'),
#  ('ADMS.csv', 'directory/ADMS.csv'),
#  ('ADNT.csv', 'directory/ADNT.csv'),
#  ('ADP.csv', 'directory/ADP.csv'),
#  ('ADPT.csv', 'directory/ADPT.csv'),
#  ('ADRE.csv', 'directory/ADRE.csv'),
#  ('ADRO.csv', 'directory/ADRO.csv'),
#  ('ADS.csv', 'directory/ADS.csv'),
#  ('ADSK.csv', 'directory/ADSK.csv'),
#  ('ADSW.csv', 'directory/ADSW.csv'),
#  ('ADT.csv', 'directory/ADT.csv'),
#  ('ADTN.csv', 'directory/ADTN.csv'),
#  ('ADUS.csv', 'directory/ADUS.csv'),
#  ('ADVM.csv', 'directory/ADVM.csv'),
#  ('ADX.csv', 'directory/ADX.csv'),
#  ('ADXN.csv', 'directory/ADXN.csv'),
#  ('ADXS.csv', 'directory/ADXS.csv'),
#  ('AE.csv', 'directory/AE.csv'),
#  ('AEB.csv', 'directory/AEB.csv'),
#  ('AEE.csv', 'directory/AEE.csv'),
#  ('AEF.csv', 'directory/AEF.csv'),
#  ('AEFC.csv', 'directory/AEFC.csv'),
#  ('AEG.csv', 'directory/AEG.csv'),
#  ('AEGN.csv', 'directory/AEGN.csv'),
#  ('AEHR.csv', 'directory/AEHR.csv'),
#  ('AEIS.csv', 'directory/AEIS.csv'),
#  ('AEL.csv', 'directory/AEL.csv'),
#  ('AEM.csv', 'directory/AEM.csv'),
#  ('AEMD.csv', 'directory/AEMD.csv'),
#  ('AEO.csv', 'directory/AEO.csv'),
#  ('AEP.csv', 'directory/AEP.csv'),
#  ('AER.csv', 'directory/AER.csv'),
#  ('AERI.csv', 'directory/AERI.csv'),
#  ('AES.csv', 'directory/AES.csv'),
#  ('AESE.csv', 'directory/AESE.csv'),
#  ('AESR.csv', 'directory/AESR.csv'),
#  ('AEY.csv', 'directory/AEY.csv'),
#  ('AEYE.csv', 'directory/AEYE.csv'),
#  ('AEZS.csv', 'directory/AEZS.csv'),
#  ('AFB.csv', 'directory/AFB.csv'),
#  ('AFC.csv', 'directory/AFC.csv'),
#  ('AFG.csv', 'directory/AFG.csv'),
#  ('AFGC.csv', 'directory/AFGC.csv'),
#  ('AFGH.csv', 'directory/AFGH.csv'),
#  ('AFH.csv', 'directory/AFH.csv'),
#  ('AFI.csv', 'directory/AFI.csv'),
#  ('AFIF.csv', 'directory/AFIF.csv'),
#  ('AFIN.csv', 'directory/AFIN.csv'),
#  ('AFINP.csv', 'directory/AFINP.csv'),
#  ('AFK.csv', 'directory/AFK.csv'),
#  ('AFL.csv', 'directory/AFL.csv'),
#  ('AFLG.csv', 'directory/AFLG.csv'),
#  ('AFMC.csv', 'directory/AFMC.csv'),
#  ('AFMD.csv', 'directory/AFMD.csv'),
#  ('AFSM.csv', 'directory/AFSM.csv'),
#  ('AFT.csv', 'directory/AFT.csv'),
#  ('AFTY.csv', 'directory/AFTY.csv'),
#  ('AFYA.csv', 'directory/AFYA.csv'),
#  ('AG.csv', 'directory/AG.csv'),
#  ('AGBA.csv', 'directory/AGBA.csv'),
#  ('AGBAU.csv', 'directory/AGBAU.csv'),
#  ('AGCO.csv', 'directory/AGCO.csv'),
#  ('AGD.csv', 'directory/AGD.csv'),
#  ('AGE.csv', 'directory/AGE.csv'),
#  ('AGEN.csv', 'directory/AGEN.csv'),
#  ('AGFS.csv', 'directory/AGFS.csv'),
#  ('AGG.csv', 'directory/AGG.csv'),
#  ('AGGP.csv', 'directory/AGGP.csv'),
#  ('AGGY.csv', 'directory/AGGY.csv'),
#  ('AGI.csv', 'directory/AGI.csv'),
#  ('AGIO.csv', 'directory/AGIO.csv'),
#  ('AGLE.csv', 'directory/AGLE.csv'),
#  ('AGM-A.csv', 'directory/AGM-A.csv'),
#  ('AGM.csv', 'directory/AGM.csv'),
#  ('AGMH.csv', 'directory/AGMH.csv'),
#  ('AGN.csv', 'directory/AGN.csv'),
#  ('AGNC.csv', 'directory/AGNC.csv'),
#  ('AGNCM.csv', 'directory/AGNCM.csv'),
#  ('AGNCN.csv', 'directory/AGNCN.csv'),
#  ('AGNCO.csv', 'directory/AGNCO.csv'),
#  ('AGNCP.csv', 'directory/AGNCP.csv'),
#  ('AGND.csv', 'directory/AGND.csv'),
#  ('AGO.csv', 'directory/AGO.csv'),
#  ('AGQ.csv', 'directory/AGQ.csv'),
#  ('AGR.csv', 'directory/AGR.csv'),
#  ('AGRO.csv', 'directory/AGRO.csv'),
#  ('AGRX.csv', 'directory/AGRX.csv'),
#  ('AGS.csv', 'directory/AGS.csv'),
#  ('AGT.csv', 'directory/AGT.csv'),
#  ('AGTC.csv', 'directory/AGTC.csv'),
#  ('AGX.csv', 'directory/AGX.csv'),
#  ('AGYS.csv', 'directory/AGYS.csv'),
#  ('AGZ.csv', 'directory/AGZ.csv'),
#  ('AGZD.csv', 'directory/AGZD.csv'),
#  ('AHC.csv', 'directory/AHC.csv'),
#  ('AHCO.csv', 'directory/AHCO.csv'),
#  ('AHH.csv', 'directory/AHH.csv'),
#  ('AHPI.csv', 'directory/AHPI.csv'),
#  ('AHT.csv', 'directory/AHT.csv'),
#  ('AI.csv', 'directory/AI.csv'),
#  ('AIA.csv', 'directory/AIA.csv'),
#  ('AIC.csv', 'directory/AIC.csv'),
#  ('AIEQ.csv', 'directory/AIEQ.csv'),
#  ('AIF.csv', 'directory/AIF.csv'),
#  ('AIG.csv', 'directory/AIG.csv'),
#  ('AIH.csv', 'directory/AIH.csv'),
#  ('AIHS.csv', 'directory/AIHS.csv'),
#  ('AIIQ.csv', 'directory/AIIQ.csv'),
#  ('AIKI.csv', 'directory/AIKI.csv'),
#  ('AIM.csv', 'directory/AIM.csv'),
#  ('AIMC.csv', 'directory/AIMC.csv'),
#  ('AIMT.csv', 'directory/AIMT.csv'),
#  ('AIN.csv', 'directory/AIN.csv'),
#  ('AINC.csv', 'directory/AINC.csv'),
#  ('AINV.csv', 'directory/AINV.csv'),
#  ('AIO.csv', 'directory/AIO.csv'),
#  ('AIQ.csv', 'directory/AIQ.csv'),
#  ('AIR.csv', 'directory/AIR.csv'),
#  ('AIRG.csv', 'directory/AIRG.csv'),
#  ('AIRI.csv', 'directory/AIRI.csv'),
#  ('AIRR.csv', 'directory/AIRR.csv'),
#  ('AIRT.csv', 'directory/AIRT.csv'),
#  ('AIRTP.csv', 'directory/AIRTP.csv'),
#  ('AIT.csv', 'directory/AIT.csv'),
#  ('AIV.csv', 'directory/AIV.csv'),
#  ('AIW.csv', 'directory/AIW.csv'),
#  ('AIZ.csv', 'directory/AIZ.csv'),
#  ('AIZP.csv', 'directory/AIZP.csv'),
#  ('AJG.csv', 'directory/AJG.csv'),
#  ('AJRD.csv', 'directory/AJRD.csv'),
#  ('AJX.csv', 'directory/AJX.csv'),
#  ('AJXA.csv', 'directory/AJXA.csv'),
#  ('AKAM.csv', 'directory/AKAM.csv'),
#  ('AKBA.csv', 'directory/AKBA.csv'),
#  ('AKCA.csv', 'directory/AKCA.csv'),
#  ('AKER.csv', 'directory/AKER.csv'),
#  ('AKG.csv', 'directory/AKG.csv'),
#  ('AKR.csv', 'directory/AKR.csv'),
#  ('AKRO.csv', 'directory/AKRO.csv'),
#  ('AKRX.csv', 'directory/AKRX.csv'),
#  ('AKTS.csv', 'directory/AKTS.csv'),
#  ('AKTX.csv', 'directory/AKTX.csv'),
#  ('AL.csv', 'directory/AL.csv'),
#  ('ALAC.csv', 'directory/ALAC.csv'),
#  ('ALACR.csv', 'directory/ALACR.csv'),
#  ('ALACU.csv', 'directory/ALACU.csv'),
#  ('ALB.csv', 'directory/ALB.csv'),
#  ('ALBO.csv', 'directory/ALBO.csv'),
#  ('ALC.csv', 'directory/ALC.csv'),
#  ('ALCO.csv', 'directory/ALCO.csv'),
#  ('ALDX.csv', 'directory/ALDX.csv'),
#  ('ALE.csv', 'directory/ALE.csv'),
#  ('ALEC.csv', 'directory/ALEC.csv'),
#  ('ALEX.csv', 'directory/ALEX.csv'),
#  ('ALFA.csv', 'directory/ALFA.csv'),
#  ('ALG.csv', 'directory/ALG.csv'),
#  ('ALGN.csv', 'directory/ALGN.csv'),
#  ('ALGR.csv', 'directory/ALGR.csv'),
#  ('ALGRU.csv', 'directory/ALGRU.csv'),
#  ('ALGT.csv', 'directory/ALGT.csv'),
#  ('ALIM.csv', 'directory/ALIM.csv'),
#  ('ALJJ.csv', 'directory/ALJJ.csv'),
#  ('ALK.csv', 'directory/ALK.csv'),
#  ('ALKS.csv', 'directory/ALKS.csv'),
#  ('ALL.csv', 'directory/ALL.csv'),
#  ('ALLE.csv', 'directory/ALLE.csv'),
#  ('ALLK.csv', 'directory/ALLK.csv'),
#  ('ALLO.csv', 'directory/ALLO.csv'),
#  ('ALLT.csv', 'directory/ALLT.csv'),
#  ('ALLY.csv', 'directory/ALLY.csv'),
#  ('ALNA.csv', 'directory/ALNA.csv'),
#  ('ALNY.csv', 'directory/ALNY.csv'),
#  ('ALO.csv', 'directory/ALO.csv'),
#  ('ALOT.csv', 'directory/ALOT.csv'),
#  ('ALPN.csv', 'directory/ALPN.csv'),
#  ('ALRM.csv', 'directory/ALRM.csv'),
#  ('ALRN.csv', 'directory/ALRN.csv'),
#  ('ALRS.csv', 'directory/ALRS.csv'),
#  ('ALSK.csv', 'directory/ALSK.csv'),
#  ('ALSN.csv', 'directory/ALSN.csv'),
#  ('ALT.csv', 'directory/ALT.csv'),
#  ('ALTG.csv', 'directory/ALTG.csv'),
#  ('ALTM.csv', 'directory/ALTM.csv'),
#  ('ALTR.csv', 'directory/ALTR.csv'),
#  ('ALTS.csv', 'directory/ALTS.csv'),
#  ('ALTY.csv', 'directory/ALTY.csv'),
#  ('ALUS.csv', 'directory/ALUS.csv'),
#  ('ALV.csv', 'directory/ALV.csv'),
#  ('ALX.csv', 'directory/ALX.csv'),
#  ('ALXN.csv', 'directory/ALXN.csv'),
#  ('ALYA.csv', 'directory/ALYA.csv'),
#  ('AM.csv', 'directory/AM.csv'),
#  ('AMAG.csv', 'directory/AMAG.csv'),
#  ('AMAL.csv', 'directory/AMAL.csv'),
#  ('AMAT.csv', 'directory/AMAT.csv'),
#  ('AMBA.csv', 'directory/AMBA.csv'),
#  ('AMBC.csv', 'directory/AMBC.csv'),
#  ('AMBO.csv', 'directory/AMBO.csv'),
#  ('AMC.csv', 'directory/AMC.csv'),
#  ('AMCA.csv', 'directory/AMCA.csv'),
#  ('AMCI.csv', 'directory/AMCI.csv'),
#  ('AMCIU.csv', 'directory/AMCIU.csv'),
#  ('AMCR.csv', 'directory/AMCR.csv'),
#  ('AMCX.csv', 'directory/AMCX.csv'),
#  ('AMD.csv', 'directory/AMD.csv'),
#  ('AME.csv', 'directory/AME.csv'),
#  ('AMED.csv', 'directory/AMED.csv'),
#  ('AMEH.csv', 'directory/AMEH.csv'),
#  ('AMG.csv', 'directory/AMG.csv'),
#  ('AMGN.csv', 'directory/AMGN.csv'),
#  ('AMH.csv', 'directory/AMH.csv'),
#  ('AMHC.csv', 'directory/AMHC.csv'),
#  ('AMHCU.csv', 'directory/AMHCU.csv'),
#  ('AMJ.csv', 'directory/AMJ.csv'),
#  ('AMK.csv', 'directory/AMK.csv'),
#  ('AMKR.csv', 'directory/AMKR.csv'),
#  ('AMLP.csv', 'directory/AMLP.csv'),
#  ('AMN.csv', 'directory/AMN.csv'),
#  ('AMNB.csv', 'directory/AMNB.csv'),
#  ('AMOM.csv', 'directory/AMOM.csv'),
#  ('AMOT.csv', 'directory/AMOT.csv'),
#  ('AMOV.csv', 'directory/AMOV.csv'),
#  ('AMP.csv', 'directory/AMP.csv'),
#  ('AMPE.csv', 'directory/AMPE.csv'),
#  ('AMPH.csv', 'directory/AMPH.csv'),
#  ('AMPY.csv', 'directory/AMPY.csv'),
#  ('AMRB.csv', 'directory/AMRB.csv'),
#  ('AMRC.csv', 'directory/AMRC.csv'),
#  ('AMRH.csv', 'directory/AMRH.csv'),
#  ('AMRK.csv', 'directory/AMRK.csv'),
#  ('AMRN.csv', 'directory/AMRN.csv'),
#  ('AMRS.csv', 'directory/AMRS.csv'),
#  ('AMRX.csv', 'directory/AMRX.csv'),
#  ('AMS.csv', 'directory/AMS.csv'),
#  ('AMSC.csv', 'directory/AMSC.csv'),
#  ('AMSF.csv', 'directory/AMSF.csv'),
#  ('AMSWA.csv', 'directory/AMSWA.csv'),
#  ('AMT.csv', 'directory/AMT.csv'),
#  ('AMTB.csv', 'directory/AMTB.csv'),
#  ('AMTBB.csv', 'directory/AMTBB.csv'),
#  ('AMTD.csv', 'directory/AMTD.csv'),
#  ('AMTX.csv', 'directory/AMTX.csv'),
#  ('AMU.csv', 'directory/AMU.csv'),
#  ('AMUB.csv', 'directory/AMUB.csv'),
#  ('AMWD.csv', 'directory/AMWD.csv'),
#  ('AMX.csv', 'directory/AMX.csv'),
#  ('AMZA.csv', 'directory/AMZA.csv'),
#  ('AMZN.csv', 'directory/AMZN.csv'),
#  ('AN.csv', 'directory/AN.csv'),
#  ('ANAB.csv', 'directory/ANAB.csv'),
#  ('ANAT.csv', 'directory/ANAT.csv'),
#  ('ANCN.csv', 'directory/ANCN.csv'),
#  ('ANDA.csv', 'directory/ANDA.csv'),
#  ('ANDAU.csv', 'directory/ANDAU.csv'),
#  ('ANDE.csv', 'directory/ANDE.csv'),
#  ('ANET.csv', 'directory/ANET.csv'),
#  ('ANF.csv', 'directory/ANF.csv'),
#  ('ANGI.csv', 'directory/ANGI.csv'),
#  ('ANGL.csv', 'directory/ANGL.csv'),
#  ('ANGO.csv', 'directory/ANGO.csv'),
#  ('ANH.csv', 'directory/ANH.csv'),
#  ('ANIK.csv', 'directory/ANIK.csv'),
#  ('ANIP.csv', 'directory/ANIP.csv'),
#  ('ANIX.csv', 'directory/ANIX.csv'),
#  ('ANPC.csv', 'directory/ANPC.csv'),
#  ('ANSS.csv', 'directory/ANSS.csv'),
#  ('ANTE.csv', 'directory/ANTE.csv'),
#  ('ANTM.csv', 'directory/ANTM.csv'),
#  ('ANVS.csv', 'directory/ANVS.csv'),
#  ('ANY.csv', 'directory/ANY.csv'),
#  ('AOA.csv', 'directory/AOA.csv'),
#  ('AOBC.csv', 'directory/AOBC.csv'),
#  ('AOD.csv', 'directory/AOD.csv'),
#  ('AOK.csv', 'directory/AOK.csv'),
#  ('AOM.csv', 'directory/AOM.csv'),
#  ('AON.csv', 'directory/AON.csv'),
#  ('AOR.csv', 'directory/AOR.csv'),
#  ('AOS.csv', 'directory/AOS.csv'),
#  ('AOSL.csv', 'directory/AOSL.csv'),
#  ('AP.csv', 'directory/AP.csv'),
#  ('APA.csv', 'directory/APA.csv'),
#  ('APAM.csv', 'directory/APAM.csv'),
#  ('APD.csv', 'directory/APD.csv'),
#  ('APDN.csv', 'directory/APDN.csv'),
#  ('APEI.csv', 'directory/APEI.csv'),
#  ('APEN.csv', 'directory/APEN.csv'),
#  ('APEX.csv', 'directory/APEX.csv'),
#  ('APH.csv', 'directory/APH.csv'),
#  ('APHA.csv', 'directory/APHA.csv'),
#  ('APLE.csv', 'directory/APLE.csv'),
#  ('APLS.csv', 'directory/APLS.csv'),
#  ('APLT.csv', 'directory/APLT.csv'),
#  ('APM.csv', 'directory/APM.csv'),
#  ('APO.csv', 'directory/APO.csv'),
#  ('APOG.csv', 'directory/APOG.csv'),
#  ('APOP.csv', 'directory/APOP.csv'),
#  ('APPF.csv', 'directory/APPF.csv'),
#  ('APPN.csv', 'directory/APPN.csv'),
#  ('APPS.csv', 'directory/APPS.csv'),
#  ('APRE.csv', 'directory/APRE.csv'),
#  ('APRN.csv', 'directory/APRN.csv'),
#  ('APT.csv', 'directory/APT.csv'),
#  ('APTO.csv', 'directory/APTO.csv'),
#  ('APTS.csv', 'directory/APTS.csv'),
#  ('APTV.csv', 'directory/APTV.csv'),
#  ('APTX.csv', 'directory/APTX.csv'),
#  ('APVO.csv', 'directory/APVO.csv'),
#  ('APWC.csv', 'directory/APWC.csv'),
#  ('APXT.csv', 'directory/APXT.csv'),
#  ('APXTU.csv', 'directory/APXTU.csv'),
#  ('APY.csv', 'directory/APY.csv'),
#  ('APYX.csv', 'directory/APYX.csv'),
#  ('AQB.csv', 'directory/AQB.csv'),
#  ('AQMS.csv', 'directory/AQMS.csv'),
#  ('AQN.csv', 'directory/AQN.csv'),
#  ('AQNA.csv', 'directory/AQNA.csv'),
#  ('AQNB.csv', 'directory/AQNB.csv'),
#  ('AQST.csv', 'directory/AQST.csv'),
#  ('AQUA.csv', 'directory/AQUA.csv'),
#  ('AR.csv', 'directory/AR.csv'),
#  ('ARA.csv', 'directory/ARA.csv'),
#  ('ARAV.csv', 'directory/ARAV.csv'),
#  ('ARAY.csv', 'directory/ARAY.csv'),
#  ('ARC.csv', 'directory/ARC.csv'),
#  ('ARCB.csv', 'directory/ARCB.csv'),
#  ('ARCC.csv', 'directory/ARCC.csv'),
#  ('ARCE.csv', 'directory/ARCE.csv'),
#  ('ARCH.csv', 'directory/ARCH.csv'),
#  ('ARCM.csv', 'directory/ARCM.csv'),
#  ('ARCO.csv', 'directory/ARCO.csv'),
#  ('ARCT.csv', 'directory/ARCT.csv'),
#  ('ARD.csv', 'directory/ARD.csv'),
#  ('ARDC.csv', 'directory/ARDC.csv'),
#  ('ARDS.csv', 'directory/ARDS.csv'),
#  ('ARDX.csv', 'directory/ARDX.csv'),
#  ('ARE.csv', 'directory/ARE.csv'),
#  ('AREC.csv', 'directory/AREC.csv'),
#  ('ARES.csv', 'directory/ARES.csv'),
#  ('ARGD.csv', 'directory/ARGD.csv'),
#  ('ARGO.csv', 'directory/ARGO.csv'),
#  ('ARGT.csv', 'directory/ARGT.csv'),
#  ('ARGX.csv', 'directory/ARGX.csv'),
#  ('ARI.csv', 'directory/ARI.csv'),
#  ('ARKF.csv', 'directory/ARKF.csv'),
#  ('ARKG.csv', 'directory/ARKG.csv'),
#  ('ARKK.csv', 'directory/ARKK.csv'),
#  ('ARKQ.csv', 'directory/ARKQ.csv'),
#  ('ARKR.csv', 'directory/ARKR.csv'),
#  ('ARKW.csv', 'directory/ARKW.csv'),
#  ('ARL.csv', 'directory/ARL.csv'),
#  ('ARLO.csv', 'directory/ARLO.csv'),
#  ('ARLP.csv', 'directory/ARLP.csv'),
#  ('ARMK.csv', 'directory/ARMK.csv'),
#  ('ARMP.csv', 'directory/ARMP.csv'),
#  ('ARMR.csv', 'directory/ARMR.csv'),
#  ('ARNA.csv', 'directory/ARNA.csv'),
#  ('ARNC.csv', 'directory/ARNC.csv'),
#  ('AROC.csv', 'directory/AROC.csv'),
#  ('AROW.csv', 'directory/AROW.csv'),
#  ('ARPO.csv', 'directory/ARPO.csv'),
#  ('ARQT.csv', 'directory/ARQT.csv'),
#  ('ARR.csv', 'directory/ARR.csv'),
#  ('ARTL.csv', 'directory/ARTL.csv'),
#  ('ARTNA.csv', 'directory/ARTNA.csv'),
#  ('ARTW.csv', 'directory/ARTW.csv'),
#  ('ARVN.csv', 'directory/ARVN.csv'),
#  ('ARW.csv', 'directory/ARW.csv'),
#  ('ARWR.csv', 'directory/ARWR.csv'),
#  ('ARYA.csv', 'directory/ARYA.csv'),
#  ('ARYAU.csv', 'directory/ARYAU.csv'),
#  ('ASA.csv', 'directory/ASA.csv'),
#  ('ASB.csv', 'directory/ASB.csv'),
#  ('ASC.csv', 'directory/ASC.csv'),
#  ('ASEA.csv', 'directory/ASEA.csv'),
#  ('ASET.csv', 'directory/ASET.csv'),
#  ('ASFI.csv', 'directory/ASFI.csv'),
#  ('ASG.csv', 'directory/ASG.csv'),
#  ('ASGN.csv', 'directory/ASGN.csv'),
#  ('ASH.csv', 'directory/ASH.csv'),
#  ('ASHR.csv', 'directory/ASHR.csv'),
#  ('ASHS.csv', 'directory/ASHS.csv'),
#  ('ASHX.csv', 'directory/ASHX.csv'),
#  ('ASIX.csv', 'directory/ASIX.csv'),
#  ('ASLN.csv', 'directory/ASLN.csv'),
#  ('ASM.csv', 'directory/ASM.csv'),
#  ('ASMB.csv', 'directory/ASMB.csv'),
#  ('ASML.csv', 'directory/ASML.csv'),
#  ('ASNA.csv', 'directory/ASNA.csv'),
#  ('ASND.csv', 'directory/ASND.csv'),
#  ('ASPN.csv', 'directory/ASPN.csv'),
#  ('ASPS.csv', 'directory/ASPS.csv'),
#  ('ASPU.csv', 'directory/ASPU.csv'),
#  ('ASR.csv', 'directory/ASR.csv'),
#  ('ASRT.csv', 'directory/ASRT.csv'),
#  ('ASRV.csv', 'directory/ASRV.csv'),
#  ('ASRVP.csv', 'directory/ASRVP.csv'),
#  ('ASTC.csv', 'directory/ASTC.csv'),
#  ('ASTE.csv', 'directory/ASTE.csv'),
#  ('ASUR.csv', 'directory/ASUR.csv'),
#  ('ASX.csv', 'directory/ASX.csv'),
#  ('ASYS.csv', 'directory/ASYS.csv'),
#  ('AT.csv', 'directory/AT.csv'),
#  ('ATAX.csv', 'directory/ATAX.csv'),
#  ('ATCO.csv', 'directory/ATCO.csv'),
#  ('ATCX.csv', 'directory/ATCX.csv'),
#  ('ATEC.csv', 'directory/ATEC.csv'),
#  ('ATEN.csv', 'directory/ATEN.csv'),
#  ('ATEX.csv', 'directory/ATEX.csv'),
#  ('ATGE.csv', 'directory/ATGE.csv'),
#  ('ATH.csv', 'directory/ATH.csv'),
#  ('ATHE.csv', 'directory/ATHE.csv'),
#  ('ATHM.csv', 'directory/ATHM.csv'),
#  ('ATHX.csv', 'directory/ATHX.csv'),
#  ('ATI.csv', 'directory/ATI.csv'),
#  ('ATIF.csv', 'directory/ATIF.csv'),
#  ('ATKR.csv', 'directory/ATKR.csv'),
#  ('ATLC.csv', 'directory/ATLC.csv'),
#  ('ATLO.csv', 'directory/ATLO.csv'),
#  ('ATMP.csv', 'directory/ATMP.csv'),
#  ('ATNI.csv', 'directory/ATNI.csv'),
#  ('ATNM.csv', 'directory/ATNM.csv'),
#  ('ATNX.csv', 'directory/ATNX.csv'),
#  ('ATO.csv', 'directory/ATO.csv'),
#  ('ATOM.csv', 'directory/ATOM.csv'),
#  ('ATOS.csv', 'directory/ATOS.csv'),
#  ('ATR.csv', 'directory/ATR.csv'),
#  ('ATRA.csv', 'directory/ATRA.csv'),
#  ('ATRC.csv', 'directory/ATRC.csv'),
#  ('ATRI.csv', 'directory/ATRI.csv'),
#  ('ATRO.csv', 'directory/ATRO.csv'),
#  ('ATRS.csv', 'directory/ATRS.csv'),
#  ('ATSG.csv', 'directory/ATSG.csv'),
#  ('ATTO.csv', 'directory/ATTO.csv'),
#  ('ATUS.csv', 'directory/ATUS.csv'),
#  ('ATV.csv', 'directory/ATV.csv'),
#  ('ATVI.csv', 'directory/ATVI.csv'),
#  ('ATXI.csv', 'directory/ATXI.csv'),
#  ('AU.csv', 'directory/AU.csv'),
#  ('AUB.csv', 'directory/AUB.csv'),
#  ('AUBN.csv', 'directory/AUBN.csv'),
#  ('AUDC.csv', 'directory/AUDC.csv'),
#  ('AUG.csv', 'directory/AUG.csv'),
#  ('AUMN.csv', 'directory/AUMN.csv'),
#  ('AUPH.csv', 'directory/AUPH.csv'),
#  ('AUSF.csv', 'directory/AUSF.csv'),
#  ('AUTL.csv', 'directory/AUTL.csv'),
#  ('AUTO.csv', 'directory/AUTO.csv'),
#  ('AUY.csv', 'directory/AUY.csv'),
#  ('AVA.csv', 'directory/AVA.csv'),
#  ('AVAL.csv', 'directory/AVAL.csv'),
#  ('AVAV.csv', 'directory/AVAV.csv'),
#  ('AVB.csv', 'directory/AVB.csv'),
#  ('AVCO.csv', 'directory/AVCO.csv'),
#  ('AVD.csv', 'directory/AVD.csv'),
#  ('AVDE.csv', 'directory/AVDE.csv'),
#  ('AVDL.csv', 'directory/AVDL.csv'),
#  ('AVDV.csv', 'directory/AVDV.csv'),
#  ('AVEM.csv', 'directory/AVEM.csv'),
#  ('AVEO.csv', 'directory/AVEO.csv'),
#  ('AVGO.csv', 'directory/AVGO.csv'),
#  ('AVGOP.csv', 'directory/AVGOP.csv'),
#  ('AVGR.csv', 'directory/AVGR.csv'),
#  ('AVH.csv', 'directory/AVH.csv'),
#  ('AVID.csv', 'directory/AVID.csv'),
#  ('AVK.csv', 'directory/AVK.csv'),
#  ('AVLR.csv', 'directory/AVLR.csv'),
#  ('AVNS.csv', 'directory/AVNS.csv'),
#  ('AVNW.csv', 'directory/AVNW.csv'),
#  ('AVRO.csv', 'directory/AVRO.csv'),
#  ('AVT.csv', 'directory/AVT.csv'),
#  ('AVTR.csv', 'directory/AVTR.csv'),
#  ('AVUS.csv', 'directory/AVUS.csv'),
#  ('AVUV.csv', 'directory/AVUV.csv'),
#  ('AVXL.csv', 'directory/AVXL.csv'),
#  ('AVY.csv', 'directory/AVY.csv'),
#  ('AVYA.csv', 'directory/AVYA.csv'),
#  ('AWAY.csv', 'directory/AWAY.csv'),
#  ('AWF.csv', 'directory/AWF.csv'),
#  ('AWI.csv', 'directory/AWI.csv'),
#  ('AWK.csv', 'directory/AWK.csv'),
#  ('AWP.csv', 'directory/AWP.csv'),
#  ('AWR.csv', 'directory/AWR.csv'),
#  ('AWRE.csv', 'directory/AWRE.csv'),
#  ('AWTM.csv', 'directory/AWTM.csv'),
#  ('AWX.csv', 'directory/AWX.csv'),
#  ('AX.csv', 'directory/AX.csv'),
#  ('AXAS.csv', 'directory/AXAS.csv'),
#  ('AXDX.csv', 'directory/AXDX.csv'),
#  ('AXE.csv', 'directory/AXE.csv'),
#  ('AXGN.csv', 'directory/AXGN.csv'),
#  ('AXGT.csv', 'directory/AXGT.csv'),
#  ('AXJL.csv', 'directory/AXJL.csv'),
#  ('AXL.csv', 'directory/AXL.csv'),
#  ('AXLA.csv', 'directory/AXLA.csv'),
#  ('AXNX.csv', 'directory/AXNX.csv'),
#  ('AXO.csv', 'directory/AXO.csv'),
#  ('AXP.csv', 'directory/AXP.csv'),
#  ('AXR.csv', 'directory/AXR.csv'),
#  ('AXS.csv', 'directory/AXS.csv'),
#  ('AXSM.csv', 'directory/AXSM.csv'),
#  ('AXTA.csv', 'directory/AXTA.csv'),
#  ('AXTI.csv', 'directory/AXTI.csv'),
#  ('AXU.csv', 'directory/AXU.csv'),
#  ('AY.csv', 'directory/AY.csv'),
#  ('AYI.csv', 'directory/AYI.csv'),
#  ('AYTU.csv', 'directory/AYTU.csv'),
#  ('AYX.csv', 'directory/AYX.csv'),
#  ('AZN.csv', 'directory/AZN.csv'),
#  ('AZO.csv', 'directory/AZO.csv'),
#  ('AZPN.csv', 'directory/AZPN.csv'),
#  ('AZRE.csv', 'directory/AZRE.csv'),
#  ('AZRX.csv', 'directory/AZRX.csv'),
#  ('AZUL.csv', 'directory/AZUL.csv'),
#  ('AZZ.csv', 'directory/AZZ.csv'),
#  ('B.csv', 'directory/B.csv'),
#  ('BA.csv', 'directory/BA.csv'),
#  ('BAB.csv', 'directory/BAB.csv'),
#  ('BABA.csv', 'directory/BABA.csv'),
#  ('BAC.csv', 'directory/BAC.csv'),
#  ('BAF.csv', 'directory/BAF.csv'),
#  ('BAH.csv', 'directory/BAH.csv'),
#  ('BAK.csv', 'directory/BAK.csv'),
#  ('BAL.csv', 'directory/BAL.csv'),
#  ('BAM.csv', 'directory/BAM.csv'),
#  ('BANC.csv', 'directory/BANC.csv'),
#  ('BAND.csv', 'directory/BAND.csv'),
#  ('BANF.csv', 'directory/BANF.csv'),
#  ('BANFP.csv', 'directory/BANFP.csv'),
#  ('BANR.csv', 'directory/BANR.csv'),
#  ('BANX.csv', 'directory/BANX.csv'),
#  ('BAP.csv', 'directory/BAP.csv'),
#  ('BAPR.csv', 'directory/BAPR.csv'),
#  ('BAR.csv', 'directory/BAR.csv'),
#  ('BASI.csv', 'directory/BASI.csv'),
#  ('BATL.csv', 'directory/BATL.csv'),
#  ('BATRA.csv', 'directory/BATRA.csv'),
#  ('BATRK.csv', 'directory/BATRK.csv'),
#  ('BATT.csv', 'directory/BATT.csv'),
#  ('BAUG.csv', 'directory/BAUG.csv'),
#  ('BAX.csv', 'directory/BAX.csv'),
#  ('BB.csv', 'directory/BB.csv'),
#  ('BBAR.csv', 'directory/BBAR.csv'),
#  ('BBAX.csv', 'directory/BBAX.csv'),
#  ('BBBY.csv', 'directory/BBBY.csv'),
#  ('BBC.csv', 'directory/BBC.csv'),
#  ('BBCA.csv', 'directory/BBCA.csv'),
#  ('BBCP.csv', 'directory/BBCP.csv'),
#  ('BBD.csv', 'directory/BBD.csv'),
#  ('BBDC.csv', 'directory/BBDC.csv'),
#  ('BBDO.csv', 'directory/BBDO.csv'),
#  ('BBEU.csv', 'directory/BBEU.csv'),
#  ('BBF.csv', 'directory/BBF.csv'),
#  ('BBGI.csv', 'directory/BBGI.csv'),
#  ('BBH.csv', 'directory/BBH.csv'),
#  ('BBI.csv', 'directory/BBI.csv'),
#  ('BBIN.csv', 'directory/BBIN.csv'),
#  ('BBIO.csv', 'directory/BBIO.csv'),
#  ('BBJP.csv', 'directory/BBJP.csv'),
#  ('BBK.csv', 'directory/BBK.csv'),
#  ('BBL.csv', 'directory/BBL.csv'),
#  ('BBN.csv', 'directory/BBN.csv'),
#  ('BBP.csv', 'directory/BBP.csv'),
#  ('BBQ.csv', 'directory/BBQ.csv'),
#  ('BBRE.csv', 'directory/BBRE.csv'),
#  ('BBSA.csv', 'directory/BBSA.csv'),
#  ('BBSI.csv', 'directory/BBSI.csv'),
#  ('BBU.csv', 'directory/BBU.csv'),
#  ('BBUS.csv', 'directory/BBUS.csv'),
#  ('BBVA.csv', 'directory/BBVA.csv'),
#  ('BBW.csv', 'directory/BBW.csv'),
#  ('BBX.csv', 'directory/BBX.csv'),
#  ('BBY.csv', 'directory/BBY.csv'),
#  ('BC.csv', 'directory/BC.csv'),
#  ('BCBP.csv', 'directory/BCBP.csv'),
#  ('BCC.csv', 'directory/BCC.csv'),
#  ('BCD.csv', 'directory/BCD.csv'),
#  ('BCDA.csv', 'directory/BCDA.csv'),
#  ('BCE.csv', 'directory/BCE.csv'),
#  ('BCEI.csv', 'directory/BCEI.csv'),
#  ('BCEL.csv', 'directory/BCEL.csv'),
#  ('BCH.csv', 'directory/BCH.csv'),
#  ('BCI.csv', 'directory/BCI.csv'),
#  ('BCLI.csv', 'directory/BCLI.csv'),
#  ('BCM.csv', 'directory/BCM.csv'),
#  ('BCML.csv', 'directory/BCML.csv'),
#  ('BCO.csv', 'directory/BCO.csv'),
#  ('BCOM.csv', 'directory/BCOM.csv'),
#  ('BCOR.csv', 'directory/BCOR.csv'),
#  ('BCOV.csv', 'directory/BCOV.csv'),
#  ('BCOW.csv', 'directory/BCOW.csv'),
#  ('BCPC.csv', 'directory/BCPC.csv'),
#  ('BCRX.csv', 'directory/BCRX.csv'),
#  ('BCS.csv', 'directory/BCS.csv'),
#  ('BCSF.csv', 'directory/BCSF.csv'),
#  ('BCTF.csv', 'directory/BCTF.csv'),
#  ('BCV.csv', 'directory/BCV.csv'),
#  ('BCX.csv', 'directory/BCX.csv'),
#  ('BCYC.csv', 'directory/BCYC.csv'),
#  ('BDC.csv', 'directory/BDC.csv'),
#  ('BDCS.csv', 'directory/BDCS.csv'),
#  ('BDCY.csv', 'directory/BDCY.csv'),
#  ('BDCZ.csv', 'directory/BDCZ.csv'),
#  ('BDEC.csv', 'directory/BDEC.csv'),
#  ('BDGE.csv', 'directory/BDGE.csv'),
#  ('BDJ.csv', 'directory/BDJ.csv'),
#  ('BDL.csv', 'directory/BDL.csv'),
#  ('BDN.csv', 'directory/BDN.csv'),
#  ('BDR.csv', 'directory/BDR.csv'),
#  ('BDRY.csv', 'directory/BDRY.csv'),
#  ('BDSI.csv', 'directory/BDSI.csv'),
#  ('BDTX.csv', 'directory/BDTX.csv'),
#  ('BDX.csv', 'directory/BDX.csv'),
#  ('BDXA.csv', 'directory/BDXA.csv'),
#  ('BE.csv', 'directory/BE.csv'),
#  ('BEAM.csv', 'directory/BEAM.csv'),
#  ('BEAT.csv', 'directory/BEAT.csv'),
#  ('BECN.csv', 'directory/BECN.csv'),
#  ('BEDU.csv', 'directory/BEDU.csv'),
#  ('BELFA.csv', 'directory/BELFA.csv'),
#  ('BELFB.csv', 'directory/BELFB.csv'),
#  ('BEN.csv', 'directory/BEN.csv'),
#  ('BEP.csv', 'directory/BEP.csv'),
#  ('BERY.csv', 'directory/BERY.csv'),
#  ('BEST.csv', 'directory/BEST.csv'),
#  ('BFAM.csv', 'directory/BFAM.csv'),
#  ('BFC.csv', 'directory/BFC.csv'),
#  ('BFEB.csv', 'directory/BFEB.csv'),
#  ('BFIN.csv', 'directory/BFIN.csv'),
#  ('BFIT.csv', 'directory/BFIT.csv'),
#  ('BFK.csv', 'directory/BFK.csv'),
#  ('BFO.csv', 'directory/BFO.csv'),
#  ('BFOR.csv', 'directory/BFOR.csv'),
#  ('BFRA.csv', 'directory/BFRA.csv'),
#  ('BFS.csv', 'directory/BFS.csv'),
#  ('BFST.csv', 'directory/BFST.csv'),
#  ('BFY.csv', 'directory/BFY.csv'),
#  ('BFYT.csv', 'directory/BFYT.csv'),
#  ('BFZ.csv', 'directory/BFZ.csv'),
#  ('BG.csv', 'directory/BG.csv'),
#  ('BGB.csv', 'directory/BGB.csv'),
#  ('BGCP.csv', 'directory/BGCP.csv'),
#  ('BGFV.csv', 'directory/BGFV.csv'),
#  ('BGG.csv', 'directory/BGG.csv'),
#  ('BGH.csv', 'directory/BGH.csv'),
#  ('BGI.csv', 'directory/BGI.csv'),
#  ('BGIO.csv', 'directory/BGIO.csv'),
#  ('BGNE.csv', 'directory/BGNE.csv'),
#  ('BGR.csv', 'directory/BGR.csv'),
#  ('BGRN.csv', 'directory/BGRN.csv'),
#  ('BGS.csv', 'directory/BGS.csv'),
#  ('BGSF.csv', 'directory/BGSF.csv'),
#  ('BGT.csv', 'directory/BGT.csv'),
#  ('BGX.csv', 'directory/BGX.csv'),
#  ('BGY.csv', 'directory/BGY.csv'),
#  ('BH.csv', 'directory/BH.csv'),
#  ('BHAT.csv', 'directory/BHAT.csv'),
#  ('BHB.csv', 'directory/BHB.csv'),
#  ('BHC.csv', 'directory/BHC.csv'),
#  ('BHE.csv', 'directory/BHE.csv'),
#  ('BHF.csv', 'directory/BHF.csv'),
#  ('BHFAL.csv', 'directory/BHFAL.csv'),
#  ('BHFAP.csv', 'directory/BHFAP.csv'),
#  ('BHK.csv', 'directory/BHK.csv'),
#  ('BHLB.csv', 'directory/BHLB.csv'),
#  ('BHP.csv', 'directory/BHP.csv'),
#  ('BHR.csv', 'directory/BHR.csv'),
#  ('BHTG.csv', 'directory/BHTG.csv'),
#  ('BHV.csv', 'directory/BHV.csv'),
#  ('BHVN.csv', 'directory/BHVN.csv'),
#  ('BIB.csv', 'directory/BIB.csv'),
#  ('BIBL.csv', 'directory/BIBL.csv'),
#  ('BICK.csv', 'directory/BICK.csv'),
#  ('BIDU.csv', 'directory/BIDU.csv'),
#  ('BIF.csv', 'directory/BIF.csv'),
#  ('BIG.csv', 'directory/BIG.csv'),
#  ('BIIB.csv', 'directory/BIIB.csv'),
#  ('BIL.csv', 'directory/BIL.csv'),
#  ('BILI.csv', 'directory/BILI.csv'),
#  ('BILL.csv', 'directory/BILL.csv'),
#  ('BIMI.csv', 'directory/BIMI.csv'),
#  ('BIO.csv', 'directory/BIO.csv'),
#  ('BIOC.csv', 'directory/BIOC.csv'),
#  ('BIOL.csv', 'directory/BIOL.csv'),
#  ('BIOX.csv', 'directory/BIOX.csv'),
#  ('BIP.csv', 'directory/BIP.csv'),
#  ('BIS.csv', 'directory/BIS.csv'),
#  ('BIT.csv', 'directory/BIT.csv'),
#  ('BITA.csv', 'directory/BITA.csv'),
#  ('BIV.csv', 'directory/BIV.csv'),
#  ('BIZD.csv', 'directory/BIZD.csv'),
#  ('BJ.csv', 'directory/BJ.csv'),
#  ('BJAN.csv', 'directory/BJAN.csv'),
#  ('BJK.csv', 'directory/BJK.csv'),
#  ('BJRI.csv', 'directory/BJRI.csv'),
#  ('BJUL.csv', 'directory/BJUL.csv'),
#  ('BJUN.csv', 'directory/BJUN.csv'),
#  ('BK.csv', 'directory/BK.csv'),
#  ('BKCC.csv', 'directory/BKCC.csv'),
#  ('BKD.csv', 'directory/BKD.csv'),
#  ('BKE.csv', 'directory/BKE.csv'),
#  ('BKEP.csv', 'directory/BKEP.csv'),
#  ('BKEPP.csv', 'directory/BKEPP.csv'),
#  ('BKF.csv', 'directory/BKF.csv'),
#  ('BKH.csv', 'directory/BKH.csv'),
#  ('BKI.csv', 'directory/BKI.csv'),
#  ('BKK.csv', 'directory/BKK.csv'),
#  ('BKLN.csv', 'directory/BKLN.csv'),
#  ('BKN.csv', 'directory/BKN.csv'),
#  ('BKNG.csv', 'directory/BKNG.csv'),
#  ('BKR.csv', 'directory/BKR.csv'),
#  ('BKSC.csv', 'directory/BKSC.csv'),
#  ('BKT.csv', 'directory/BKT.csv'),
#  ('BKTI.csv', 'directory/BKTI.csv'),
#  ('BKU.csv', 'directory/BKU.csv'),
#  ('BKYI.csv', 'directory/BKYI.csv'),
#  ('BL.csv', 'directory/BL.csv'),
#  ('BLBD.csv', 'directory/BLBD.csv'),
#  ('BLCM.csv', 'directory/BLCM.csv'),
#  ('BLCN.csv', 'directory/BLCN.csv'),
#  ('BLD.csv', 'directory/BLD.csv'),
#  ('BLDP.csv', 'directory/BLDP.csv'),
#  ('BLDR.csv', 'directory/BLDR.csv'),
#  ('BLE.csv', 'directory/BLE.csv'),
#  ('BLES.csv', 'directory/BLES.csv'),
#  ('BLFS.csv', 'directory/BLFS.csv'),
#  ('BLHY.csv', 'directory/BLHY.csv'),
#  ('BLIN.csv', 'directory/BLIN.csv'),
#  ('BLK.csv', 'directory/BLK.csv'),
#  ('BLKB.csv', 'directory/BLKB.csv'),
#  ('BLL.csv', 'directory/BLL.csv'),
#  ('BLMN.csv', 'directory/BLMN.csv'),
#  ('BLNK.csv', 'directory/BLNK.csv'),
#  ('BLOK.csv', 'directory/BLOK.csv'),
#  ('BLPH.csv', 'directory/BLPH.csv'),
#  ('BLRX.csv', 'directory/BLRX.csv'),
#  ('BLU.csv', 'directory/BLU.csv'),
#  ('BLUE.csv', 'directory/BLUE.csv'),
#  ('BLV.csv', 'directory/BLV.csv'),
#  ('BLW.csv', 'directory/BLW.csv'),
#  ('BLX.csv', 'directory/BLX.csv'),
#  ('BMA.csv', 'directory/BMA.csv'),
#  ('BMAR.csv', 'directory/BMAR.csv'),
#  ('BMCH.csv', 'directory/BMCH.csv'),
#  ('BME.csv', 'directory/BME.csv'),
#  ('BMEZ.csv', 'directory/BMEZ.csv'),
#  ('BMI.csv', 'directory/BMI.csv'),
#  ('BMLP.csv', 'directory/BMLP.csv'),
#  ('BMO.csv', 'directory/BMO.csv'),
#  ('BMRA.csv', 'directory/BMRA.csv'),
#  ('BMRC.csv', 'directory/BMRC.csv'),
#  ('BMRN.csv', 'directory/BMRN.csv'),
#  ('BMTC.csv', 'directory/BMTC.csv'),
#  ('BMY.csv', 'directory/BMY.csv'),
#  ('BND.csv', 'directory/BND.csv'),
#  ('BNDC.csv', 'directory/BNDC.csv'),
#  ('BNDW.csv', 'directory/BNDW.csv'),
#  ('BNDX.csv', 'directory/BNDX.csv'),
#  ('BNED.csv', 'directory/BNED.csv'),
#  ('BNFT.csv', 'directory/BNFT.csv'),
#  ('BNGO.csv', 'directory/BNGO.csv'),
#  ('BNKD.csv', 'directory/BNKD.csv'),
#  ('BNKO.csv', 'directory/BNKO.csv'),
#  ('BNKU.csv', 'directory/BNKU.csv'),
#  ('BNKZ.csv', 'directory/BNKZ.csv'),
#  ('BNO.csv', 'directory/BNO.csv'),
#  ('BNOV.csv', 'directory/BNOV.csv'),
#  ('BNS.csv', 'directory/BNS.csv'),
#  ('BNSO.csv', 'directory/BNSO.csv'),
#  ('BNTC.csv', 'directory/BNTC.csv'),
#  ('BNTX.csv', 'directory/BNTX.csv'),
#  ('BNY.csv', 'directory/BNY.csv'),
#  ('BOCH.csv', 'directory/BOCH.csv'),
#  ('BOCT.csv', 'directory/BOCT.csv'),
#  ('BOE.csv', 'directory/BOE.csv'),
#  ('BOH.csv', 'directory/BOH.csv'),
#  ('BOIL.csv', 'directory/BOIL.csv'),
#  ('BOKF.csv', 'directory/BOKF.csv'),
#  ('BOKFL.csv', 'directory/BOKFL.csv'),
#  ('BOMN.csv', 'directory/BOMN.csv'),
#  ('BOND.csv', 'directory/BOND.csv'),
#  ('BOOM.csv', 'directory/BOOM.csv'),
#  ('BOOT.csv', 'directory/BOOT.csv'),
#  ('BORR.csv', 'directory/BORR.csv'),
#  ('BOSC.csv', 'directory/BOSC.csv'),
#  ('BOSS.csv', 'directory/BOSS.csv'),
#  ('BOTJ.csv', 'directory/BOTJ.csv'),
#  ('BOTZ.csv', 'directory/BOTZ.csv'),
#  ('BOUT.csv', 'directory/BOUT.csv'),
#  ('BOX.csv', 'directory/BOX.csv'),
#  ('BOXL.csv', 'directory/BOXL.csv'),
#  ('BP.csv', 'directory/BP.csv'),
#  ('BPFH.csv', 'directory/BPFH.csv'),
#  ('BPMC.csv', 'directory/BPMC.csv'),
#  ('BPMP.csv', 'directory/BPMP.csv'),
#  ('BPMX.csv', 'directory/BPMX.csv'),
#  ('BPOP.csv', 'directory/BPOP.csv'),
#  ('BPOPM.csv', 'directory/BPOPM.csv'),
#  ('BPOPN.csv', 'directory/BPOPN.csv'),
#  ('BPRN.csv', 'directory/BPRN.csv'),
#  ('BPT.csv', 'directory/BPT.csv'),
#  ('BPTH.csv', 'directory/BPTH.csv'),
#  ('BPY.csv', 'directory/BPY.csv'),
#  ('BPYPN.csv', 'directory/BPYPN.csv'),
#  ('BPYPO.csv', 'directory/BPYPO.csv'),
#  ('BPYPP.csv', 'directory/BPYPP.csv'),
#  ('BPYU.csv', 'directory/BPYU.csv'),
#  ('BPYUP.csv', 'directory/BPYUP.csv'),
#  ('BQH.csv', 'directory/BQH.csv'),
#  ('BR.csv', 'directory/BR.csv'),
#  ('BRBR.csv', 'directory/BRBR.csv'),
#  ('BRBS.csv', 'directory/BRBS.csv'),
#  ('BRC.csv', 'directory/BRC.csv'),
#  ('BREW.csv', 'directory/BREW.csv'),
#  ('BRF.csv', 'directory/BRF.csv'),
#  ('BRFS.csv', 'directory/BRFS.csv'),
#  ('BRG.csv', 'directory/BRG.csv'),
#  ('BRID.csv', 'directory/BRID.csv'),
#  ('BRKL.csv', 'directory/BRKL.csv'),
#  ('BRKR.csv', 'directory/BRKR.csv'),
#  ('BRKS.csv', 'directory/BRKS.csv'),
#  ('BRMK.csv', 'directory/BRMK.csv'),
#  ('BRN.csv', 'directory/BRN.csv'),
#  ('BRO.csv', 'directory/BRO.csv'),
#  ('BROG.csv', 'directory/BROG.csv'),
#  ('BRP.csv', 'directory/BRP.csv'),
#  ('BRPA.csv', 'directory/BRPA.csv'),
#  ('BRPAR.csv', 'directory/BRPAR.csv'),
#  ('BRPAU.csv', 'directory/BRPAU.csv'),
#  ('BRQS.csv', 'directory/BRQS.csv'),
#  ('BRT.csv', 'directory/BRT.csv'),
#  ('BRX.csv', 'directory/BRX.csv'),
#  ('BRY.csv', 'directory/BRY.csv'),
#  ('BRZU.csv', 'directory/BRZU.csv'),
#  ('BSA.csv', 'directory/BSA.csv'),
#  ('BSAC.csv', 'directory/BSAC.csv'),
#  ('BSAE.csv', 'directory/BSAE.csv'),
#  ('BSBE.csv', 'directory/BSBE.csv'),
#  ('BSBK.csv', 'directory/BSBK.csv'),
#  ('BSBR.csv', 'directory/BSBR.csv'),
#  ('BSCE.csv', 'directory/BSCE.csv'),
#  ('BSCK.csv', 'directory/BSCK.csv'),
#  ('BSCL.csv', 'directory/BSCL.csv'),
#  ('BSCM.csv', 'directory/BSCM.csv'),
#  ('BSCN.csv', 'directory/BSCN.csv'),
#  ('BSCO.csv', 'directory/BSCO.csv'),
#  ('BSCP.csv', 'directory/BSCP.csv'),
#  ('BSCQ.csv', 'directory/BSCQ.csv'),
#  ('BSCR.csv', 'directory/BSCR.csv'),
#  ('BSCS.csv', 'directory/BSCS.csv'),
#  ('BSCT.csv', 'directory/BSCT.csv'),
#  ('BSD.csv', 'directory/BSD.csv'),
#  ('BSDE.csv', 'directory/BSDE.csv'),
#  ('BSE.csv', 'directory/BSE.csv'),
#  ('BSEP.csv', 'directory/BSEP.csv'),
#  ('BSET.csv', 'directory/BSET.csv'),
#  ('BSGM.csv', 'directory/BSGM.csv'),
#  ('BSIG.csv', 'directory/BSIG.csv'),
#  ('BSJK.csv', 'directory/BSJK.csv'),
#  ('BSJL.csv', 'directory/BSJL.csv'),
#  ('BSJM.csv', 'directory/BSJM.csv'),
#  ('BSJN.csv', 'directory/BSJN.csv'),
#  ('BSJO.csv', 'directory/BSJO.csv'),
#  ('BSJP.csv', 'directory/BSJP.csv'),
#  ('BSJQ.csv', 'directory/BSJQ.csv'),
#  ('BSJR.csv', 'directory/BSJR.csv'),
#  ('BSL.csv', 'directory/BSL.csv'),
#  ('BSM.csv', 'directory/BSM.csv'),
#  ('BSML.csv', 'directory/BSML.csv'),
#  ('BSMM.csv', 'directory/BSMM.csv'),
#  ('BSMN.csv', 'directory/BSMN.csv'),
#  ('BSMO.csv', 'directory/BSMO.csv'),
#  ('BSMP.csv', 'directory/BSMP.csv'),
#  ('BSMQ.csv', 'directory/BSMQ.csv'),
#  ('BSMR.csv', 'directory/BSMR.csv'),
#  ('BSMS.csv', 'directory/BSMS.csv'),
#  ('BSMT.csv', 'directory/BSMT.csv'),
#  ('BSMX.csv', 'directory/BSMX.csv'),
#  ('BSQR.csv', 'directory/BSQR.csv'),
#  ('BSRR.csv', 'directory/BSRR.csv'),
#  ('BST.csv', 'directory/BST.csv'),
#  ('BSTC.csv', 'directory/BSTC.csv'),
#  ('BSTZ.csv', 'directory/BSTZ.csv'),
#  ('BSV.csv', 'directory/BSV.csv'),
#  ('BSVN.csv', 'directory/BSVN.csv'),
#  ('BSX.csv', 'directory/BSX.csv'),
#  ('BTA.csv', 'directory/BTA.csv'),
#  ('BTAI.csv', 'directory/BTAI.csv'),
#  ('BTAL.csv', 'directory/BTAL.csv'),
#  ('BTE.csv', 'directory/BTE.csv'),
#  ('BTEC.csv', 'directory/BTEC.csv'),
#  ('BTG.csv', 'directory/BTG.csv'),
#  ('BTI.csv', 'directory/BTI.csv'),
#  ('BTN.csv', 'directory/BTN.csv'),
#  ('BTO.csv', 'directory/BTO.csv'),
#  ('BTT.csv', 'directory/BTT.csv'),
#  ('BTU.csv', 'directory/BTU.csv'),
#  ('BTYS.csv', 'directory/BTYS.csv'),
#  ('BTZ.csv', 'directory/BTZ.csv'),
#  ('BUD.csv', 'directory/BUD.csv'),
#  ('BUG.csv', 'directory/BUG.csv'),
#  ('BUI.csv', 'directory/BUI.csv'),
#  ('BUL.csv', 'directory/BUL.csv'),
#  ('BURL.csv', 'directory/BURL.csv'),
#  ('BUSE.csv', 'directory/BUSE.csv'),
#  ('BUY.csv', 'directory/BUY.csv'),
#  ('BUYN.csv', 'directory/BUYN.csv'),
#  ('BUYZ.csv', 'directory/BUYZ.csv'),
#  ('BV.csv', 'directory/BV.csv'),
#  ('BVAL.csv', 'directory/BVAL.csv'),
#  ('BVN.csv', 'directory/BVN.csv'),
#  ('BVSN.csv', 'directory/BVSN.csv'),
#  ...]

# %%
# function for creating data frames of each csv file with a new column Symbol

def read_and_add(file_info):
    data = dd.read_csv(file_info[1])
    data["Symbol"] = file_info[0][:-4]
    return data

# %%
read_and_add(a[0])
# Out:
# Dask DataFrame Structure:
#                  Date     Open     High      Low    Close Adj Close Volume  Symbol
# npartitions=1
#                object  float64  float64  float64  float64   float64  int64  object
#                   ...      ...      ...      ...      ...       ...    ...     ...
# Dask Name: assign, 2 graph layers

# %%
# function for concatenating all of the data frames. 

def dask_read(files):
    dfs = [read_and_add(file_info) for file_info in files]
    df = dd.concat(dfs)
    df = df.compute()
    return df

# %%
data = dask_read(a)
data
# Out:
#             Date       Open       High        Low      Close  Adj Close
# 0     1999-11-18  32.546494  35.765381  28.612303  31.473534  27.068665  \
# 1     1999-11-19  30.713520  30.758226  28.478184  28.880543  24.838577
# 2     1999-11-22  29.551144  31.473534  28.657009  31.473534  27.068665
# 3     1999-11-23  30.400572  31.205294  28.612303  28.612303  24.607880
# 4     1999-11-24  28.701717  29.998211  28.612303  29.372318  25.261524
# ...          ...        ...        ...        ...        ...        ...
# 4049  2020-03-26  10.230000  11.430000  10.230000  11.100000  11.100000
# 4050  2020-03-27  10.700000  10.980000  10.060000  10.300000  10.300000
# 4051  2020-03-30  10.160000  11.060000  10.160000  10.800000  10.800000
# 4052  2020-03-31  10.680000  11.140000  10.590000  11.070000  11.070000
# 4053  2020-04-01  11.160000  11.160000  10.510000  10.920000  10.920000
#
#           Volume Symbol
# 0     62546300.0      A
# 1     15234100.0      A
# 2      6577800.0      A
# 3      5975600.0      A
# 4      4843200.0      A
# ...          ...    ...
# 4049    189500.0   ZYXI
# 4050    145000.0   ZYXI
# 4051    162300.0   ZYXI
# 4052    280400.0   ZYXI
# 4053    315900.0   ZYXI
#
# [28148368 rows x 8 columns]

# %%
# function for merging meta dataframe and the previously created dataframe with all csv files.

def merge(data, meta_df):
    columns = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Symbol", "Security Name"]
    merged_df = meta_df.merge(data, on='Symbol')
    merged_df = merged_df[columns]
    return merged_df

# %%
df = merge(data, meta_df)
df
# Out:
#                 Date       Open       High        Low      Close  Adj Close
# 0         1999-11-18  32.546494  35.765381  28.612303  31.473534  27.068665  \
# 1         1999-11-19  30.713520  30.758226  28.478184  28.880543  24.838577
# 2         1999-11-22  29.551144  31.473534  28.657009  31.473534  27.068665
# 3         1999-11-23  30.400572  31.205294  28.612303  28.612303  24.607880
# 4         1999-11-24  28.701717  29.998211  28.612303  29.372318  25.261524
# ...              ...        ...        ...        ...        ...        ...
# 28126845  2020-03-26  10.230000  11.430000  10.230000  11.100000  11.100000
# 28126846  2020-03-27  10.700000  10.980000  10.060000  10.300000  10.300000
# 28126847  2020-03-30  10.160000  11.060000  10.160000  10.800000  10.800000
# 28126848  2020-03-31  10.680000  11.140000  10.590000  11.070000  11.070000
# 28126849  2020-04-01  11.160000  11.160000  10.510000  10.920000  10.920000
#
#               Volume Symbol                            Security Name
# 0         62546300.0      A  Agilent Technologies, Inc. Common Stock
# 1         15234100.0      A  Agilent Technologies, Inc. Common Stock
# 2          6577800.0      A  Agilent Technologies, Inc. Common Stock
# 3          5975600.0      A  Agilent Technologies, Inc. Common Stock
# 4          4843200.0      A  Agilent Technologies, Inc. Common Stock
# ...              ...    ...                                      ...
# 28126845    189500.0   ZYXI               Zynex, Inc. - Common Stock
# 28126846    145000.0   ZYXI               Zynex, Inc. - Common Stock
# 28126847    162300.0   ZYXI               Zynex, Inc. - Common Stock
# 28126848    280400.0   ZYXI               Zynex, Inc. - Common Stock
# 28126849    315900.0   ZYXI               Zynex, Inc. - Common Stock
#
# [28126850 rows x 9 columns]

# %%
# function to convert the resulting dataset into parquet

def write_to_parquet(df, out_loc):
    df.to_parquet(out_loc)

# %%
if __name__ == '__main__':
    #location = "symbols_valid_meta.csv"
    #directory = "archive"
    #out_loc = "stage/outpu1.parquet"
    location = input("Enter metadata file full location with the file name: ")
    directory = input("enter the directory where etfs and stocks data is present: ")
    out_loc = input("full location where you want to write the outfile file: ")
    meta_df = reading_metadata(location)
    files = get_file_details(directory)
    df = dask_read(files)
    df = merge(df, meta_df)
    write_to_parquet(df, out_loc)
# Out:
# Enter metadata file full location with the file name:  symbols_valid_meta.csv
# enter the directory where etfs and stocks data is present:  directory
# full location where you want to write the outfile file:  output1.parquet
